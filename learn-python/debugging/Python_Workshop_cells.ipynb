# %%
# How to open a file

f = open('interesting_stuff.csv')
f
# Out:
# <_io.TextIOWrapper name='interesting_stuff.csv' mode='r' encoding='UTF-8'>

# %%
# Reading whats in the file 
lines = f.readlines()
lines
# Out:
# ['Week,learn python: (Worldwide),learn piano: (Worldwide),learn german: (Worldwide)\n',
#  '2017-05-21,61,47,41\n',
#  '2017-05-28,57,44,43\n',
#  '2017-06-04,56,46,42\n',
#  '2017-06-11,63,44,48\n',
#  '2017-06-18,59,41,45\n',
#  '2017-06-25,56,35,47\n',
#  '2017-07-02,57,51,48\n',
#  '2017-07-09,64,41,48\n',
#  '2017-07-16,62,44,48\n',
#  '2017-07-23,62,43,47\n',
#  '2017-07-30,63,45,46\n',
#  '2017-08-06,58,40,40\n',
#  '2017-08-13,63,40,40\n',
#  '2017-08-20,62,42,41\n',
#  '2017-08-27,52,40,42\n',
#  '2017-09-03,64,40,39\n',
#  '2017-09-10,58,46,47\n',
#  '2017-09-17,61,44,46\n',
#  '2017-09-24,66,42,51\n',
#  '2017-10-01,61,44,41\n',
#  '2017-10-08,59,42,43\n',
#  '2017-10-15,58,44,49\n',
#  '2017-10-22,55,43,43\n',
#  '2017-10-29,54,42,39\n',
#  '2017-11-05,63,47,45\n',
#  '2017-11-12,59,43,48\n',
#  '2017-11-19,62,45,40\n',
#  '2017-11-26,65,46,44\n',
#  '2017-12-03,63,49,49\n',
#  '2017-12-10,62,54,39\n',
#  '2017-12-17,59,51,35\n',
#  '2017-12-24,57,67,38\n',
#  '2017-12-31,59,61,42\n',
#  '2018-01-07,65,52,46\n',
#  '2018-01-14,66,44,47\n',
#  '2018-01-21,65,49,50\n',
#  '2018-01-28,64,48,46\n',
#  '2018-02-04,62,44,44\n',
#  '2018-02-11,58,42,44\n',
#  '2018-02-18,56,43,38\n',
#  '2018-02-25,61,41,39\n',
#  '2018-03-04,59,44,41\n',
#  '2018-03-11,67,41,41\n',
#  '2018-03-18,60,48,44\n',
#  '2018-03-25,60,47,42\n',
#  '2018-04-01,60,43,43\n',
#  '2018-04-08,59,42,43\n',
#  '2018-04-15,66,39,40\n',
#  '2018-04-22,60,39,41\n',
#  '2018-04-29,59,41,39\n',
#  '2018-05-06,64,37,41\n',
#  '2018-05-13,61,37,43\n',
#  '2018-05-20,66,42,38\n',
#  '2018-05-27,61,37,40\n',
#  '2018-06-03,65,42,39\n',
#  '2018-06-10,59,34,42\n',
#  '2018-06-17,61,36,46\n',
#  '2018-06-24,67,35,37\n',
#  '2018-07-01,62,38,43\n',
#  '2018-07-08,63,37,45\n',
#  '2018-07-15,61,38,48\n',
#  '2018-07-22,69,36,38\n',
#  '2018-07-29,70,42,42\n',
#  '2018-08-05,68,42,44\n',
#  '2018-08-12,61,40,38\n',
#  '2018-08-19,64,41,39\n',
#  '2018-08-26,61,43,43\n',
#  '2018-09-02,63,41,48\n',
#  '2018-09-09,61,42,40\n',
#  '2018-09-16,60,43,44\n',
#  '2018-09-23,65,39,40\n',
#  '2018-09-30,62,42,46\n',
#  '2018-10-07,64,39,41\n',
#  '2018-10-14,62,42,39\n',
#  '2018-10-21,60,42,37\n',
#  '2018-10-28,58,40,36\n',
#  '2018-11-04,59,45,36\n',
#  '2018-11-11,61,43,37\n',
#  '2018-11-18,52,51,38\n',
#  '2018-11-25,59,52,41\n',
#  '2018-12-02,63,54,41\n',
#  '2018-12-09,64,52,37\n',
#  '2018-12-16,58,53,34\n',
#  '2018-12-23,50,70,38\n',
#  '2018-12-30,54,62,42\n',
#  '2019-01-06,59,50,47\n',
#  '2019-01-13,59,56,43\n',
#  '2019-01-20,59,48,41\n',
#  '2019-01-27,68,46,40\n',
#  '2019-02-03,63,43,42\n',
#  '2019-02-10,61,43,45\n',
#  '2019-02-17,66,51,39\n',
#  '2019-02-24,63,47,37\n',
#  '2019-03-03,55,46,40\n',
#  '2019-03-10,60,38,39\n',
#  '2019-03-17,58,42,33\n',
#  '2019-03-24,59,39,39\n',
#  '2019-03-31,60,38,43\n',
#  '2019-04-07,66,42,38\n',
#  '2019-04-14,60,39,38\n',
#  '2019-04-21,62,34,39\n',
#  '2019-04-28,59,39,40\n',
#  '2019-05-05,63,39,37\n',
#  '2019-05-12,66,34,35\n',
#  '2019-05-19,64,34,42\n',
#  '2019-05-26,69,38,38\n',
#  '2019-06-02,66,42,33\n',
#  '2019-06-09,72,39,41\n',
#  '2019-06-16,71,40,38\n',
#  '2019-06-23,68,41,42\n',
#  '2019-06-30,64,39,40\n',
#  '2019-07-07,75,38,44\n',
#  '2019-07-14,67,38,41\n',
#  '2019-07-21,71,44,39\n',
#  '2019-07-28,71,38,37\n',
#  '2019-08-04,66,33,34\n',
#  '2019-08-11,69,41,41\n',
#  '2019-08-18,78,41,48\n',
#  '2019-08-25,65,38,40\n',
#  '2019-09-01,74,40,45\n',
#  '2019-09-08,73,48,46\n',
#  '2019-09-15,76,42,44\n',
#  '2019-09-22,69,41,48\n',
#  '2019-09-29,67,41,43\n',
#  '2019-10-06,65,40,36\n',
#  '2019-10-13,71,39,42\n',
#  '2019-10-20,63,41,39\n',
#  '2019-10-27,66,38,40\n',
#  '2019-11-03,67,48,42\n',
#  '2019-11-10,68,41,48\n',
#  '2019-11-17,69,41,40\n',
#  '2019-11-24,64,46,39\n',
#  '2019-12-01,69,47,40\n',
#  '2019-12-08,64,42,34\n',
#  '2019-12-15,71,46,40\n',
#  '2019-12-22,64,60,39\n',
#  '2019-12-29,56,56,41\n',
#  '2020-01-05,77,52,41\n',
#  '2020-01-12,69,47,44\n',
#  '2020-01-19,71,42,43\n',
#  '2020-01-26,69,42,40\n',
#  '2020-02-02,68,47,39\n',
#  '2020-02-09,71,40,39\n',
#  '2020-02-16,73,43,40\n',
#  '2020-02-23,72,40,42\n',
#  '2020-03-01,64,44,38\n',
#  '2020-03-08,59,38,34\n',
#  '2020-03-15,70,67,42\n',
#  '2020-03-22,79,96,48\n',
#  '2020-03-29,86,100,46\n',
#  '2020-04-05,79,89,45\n',
#  '2020-04-12,84,96,54\n',
#  '2020-04-19,81,82,46\n',
#  '2020-04-26,84,81,49\n',
#  '2020-05-03,80,69,47\n',
#  '2020-05-10,74,67,45\n',
#  '2020-05-17,79,67,43\n',
#  '2020-05-24,75,55,41\n',
#  '2020-05-31,67,51,42\n',
#  '2020-06-07,75,54,44\n',
#  '2020-06-14,72,51,44\n',
#  '2020-06-21,70,52,45\n',
#  '2020-06-28,79,50,43\n',
#  '2020-07-05,76,50,41\n',
#  '2020-07-12,78,49,43\n',
#  '2020-07-19,75,44,47\n',
#  '2020-07-26,73,50,42\n',
#  '2020-08-02,67,49,40\n',
#  '2020-08-09,73,48,40\n',
#  '2020-08-16,70,44,40\n',
#  '2020-08-23,70,43,43\n',
#  '2020-08-30,71,49,42\n',
#  '2020-09-06,67,49,39\n',
#  '2020-09-13,64,43,44\n',
#  '2020-09-20,62,46,43\n',
#  '2020-09-27,61,44,37\n',
#  '2020-10-04,62,43,40\n',
#  '2020-10-11,50,43,38\n',
#  '2020-10-18,55,42,38\n',
#  '2020-10-25,52,39,34\n',
#  '2020-11-01,42,41,28\n',
#  '2020-11-08,52,44,35\n',
#  '2020-11-15,53,45,41\n',
#  '2020-11-22,51,42,35\n',
#  '2020-11-29,50,44,34\n',
#  '2020-12-06,54,43,35\n',
#  '2020-12-13,52,42,36\n',
#  '2020-12-20,48,56,34\n',
#  '2020-12-27,54,67,36\n',
#  '2021-01-03,58,58,42\n',
#  '2021-01-10,56,52,37\n',
#  '2021-01-17,49,43,38\n',
#  '2021-01-24,50,49,35\n',
#  '2021-01-31,51,47,40\n',
#  '2021-02-07,51,46,33\n',
#  '2021-02-14,54,40,33\n',
#  '2021-02-21,46,39,35\n',
#  '2021-02-28,51,39,32\n',
#  '2021-03-07,47,40,34\n',
#  '2021-03-14,48,38,33\n',
#  '2021-03-21,54,34,34\n',
#  '2021-03-28,50,36,29\n',
#  '2021-04-04,53,35,35\n',
#  '2021-04-11,48,35,41\n',
#  '2021-04-18,51,38,32\n',
#  '2021-04-25,57,35,34\n',
#  '2021-05-02,53,36,31\n',
#  '2021-05-09,61,36,33\n',
#  '2021-05-16,58,35,32\n',
#  '2021-05-23,57,36,39\n',
#  '2021-05-30,62,36,36\n',
#  '2021-06-06,53,33,34\n',
#  '2021-06-13,59,34,30\n',
#  '2021-06-20,55,32,32\n',
#  '2021-06-27,52,34,32\n',
#  '2021-07-04,57,36,32\n',
#  '2021-07-11,62,34,34\n',
#  '2021-07-18,54,35,34\n',
#  '2021-07-25,56,31,37\n',
#  '2021-08-01,51,29,33\n',
#  '2021-08-08,51,32,33\n',
#  '2021-08-15,52,38,30\n',
#  '2021-08-22,53,31,37\n',
#  '2021-08-29,49,31,36\n',
#  '2021-09-05,52,34,41\n',
#  '2021-09-12,50,37,34\n',
#  '2021-09-19,58,38,38\n',
#  '2021-09-26,55,34,35\n',
#  '2021-10-03,50,33,39\n',
#  '2021-10-10,50,36,35\n',
#  '2021-10-17,55,32,32\n',
#  '2021-10-24,54,34,34\n',
#  '2021-10-31,50,42,33\n',
#  '2021-11-07,53,38,36\n',
#  '2021-11-14,53,37,38\n',
#  '2021-11-21,51,40,33\n',
#  '2021-11-28,52,40,32\n',
#  '2021-12-05,58,43,30\n',
#  '2021-12-12,57,41,36\n',
#  '2021-12-19,51,51,34\n',
#  '2021-12-26,52,60,32\n',
#  '2022-01-02,59,49,35\n',
#  '2022-01-09,54,48,37\n',
#  '2022-01-16,59,39,34\n',
#  '2022-01-23,57,38,36\n',
#  '2022-01-30,54,40,37\n',
#  '2022-02-06,58,41,35\n',
#  '2022-02-13,53,38,35\n',
#  '2022-02-20,54,37,33\n',
#  '2022-02-27,56,34,36\n',
#  '2022-03-06,55,35,33\n',
#  '2022-03-13,49,31,31\n',
#  '2022-03-20,57,31,37\n',
#  '2022-03-27,52,33,32\n',
#  '2022-04-03,58,34,30\n',
#  '2022-04-10,52,34,33\n',
#  '2022-04-17,54,35,32\n',
#  '2022-04-24,55,28,30\n',
#  '2022-05-01,53,33,35\n',
#  '2022-05-08,53,31,34\n',
#  '2022-05-15,0,0,0\n']

# %%
# how many lines are there?
len(lines)
# Out:
# 262

# %%
# get the labels of the data

labels = lines[0].split(',')
labels
# Out:
# ['Week',
#  'learn python: (Worldwide)',
#  'learn piano: (Worldwide)',
#  'learn german: (Worldwide)\n']

# %%
# get the data without the labels 

data = lines[1:]
data
# Out:
# ['2017-05-21,61,47,41\n',
#  '2017-05-28,57,44,43\n',
#  '2017-06-04,56,46,42\n',
#  '2017-06-11,63,44,48\n',
#  '2017-06-18,59,41,45\n',
#  '2017-06-25,56,35,47\n',
#  '2017-07-02,57,51,48\n',
#  '2017-07-09,64,41,48\n',
#  '2017-07-16,62,44,48\n',
#  '2017-07-23,62,43,47\n',
#  '2017-07-30,63,45,46\n',
#  '2017-08-06,58,40,40\n',
#  '2017-08-13,63,40,40\n',
#  '2017-08-20,62,42,41\n',
#  '2017-08-27,52,40,42\n',
#  '2017-09-03,64,40,39\n',
#  '2017-09-10,58,46,47\n',
#  '2017-09-17,61,44,46\n',
#  '2017-09-24,66,42,51\n',
#  '2017-10-01,61,44,41\n',
#  '2017-10-08,59,42,43\n',
#  '2017-10-15,58,44,49\n',
#  '2017-10-22,55,43,43\n',
#  '2017-10-29,54,42,39\n',
#  '2017-11-05,63,47,45\n',
#  '2017-11-12,59,43,48\n',
#  '2017-11-19,62,45,40\n',
#  '2017-11-26,65,46,44\n',
#  '2017-12-03,63,49,49\n',
#  '2017-12-10,62,54,39\n',
#  '2017-12-17,59,51,35\n',
#  '2017-12-24,57,67,38\n',
#  '2017-12-31,59,61,42\n',
#  '2018-01-07,65,52,46\n',
#  '2018-01-14,66,44,47\n',
#  '2018-01-21,65,49,50\n',
#  '2018-01-28,64,48,46\n',
#  '2018-02-04,62,44,44\n',
#  '2018-02-11,58,42,44\n',
#  '2018-02-18,56,43,38\n',
#  '2018-02-25,61,41,39\n',
#  '2018-03-04,59,44,41\n',
#  '2018-03-11,67,41,41\n',
#  '2018-03-18,60,48,44\n',
#  '2018-03-25,60,47,42\n',
#  '2018-04-01,60,43,43\n',
#  '2018-04-08,59,42,43\n',
#  '2018-04-15,66,39,40\n',
#  '2018-04-22,60,39,41\n',
#  '2018-04-29,59,41,39\n',
#  '2018-05-06,64,37,41\n',
#  '2018-05-13,61,37,43\n',
#  '2018-05-20,66,42,38\n',
#  '2018-05-27,61,37,40\n',
#  '2018-06-03,65,42,39\n',
#  '2018-06-10,59,34,42\n',
#  '2018-06-17,61,36,46\n',
#  '2018-06-24,67,35,37\n',
#  '2018-07-01,62,38,43\n',
#  '2018-07-08,63,37,45\n',
#  '2018-07-15,61,38,48\n',
#  '2018-07-22,69,36,38\n',
#  '2018-07-29,70,42,42\n',
#  '2018-08-05,68,42,44\n',
#  '2018-08-12,61,40,38\n',
#  '2018-08-19,64,41,39\n',
#  '2018-08-26,61,43,43\n',
#  '2018-09-02,63,41,48\n',
#  '2018-09-09,61,42,40\n',
#  '2018-09-16,60,43,44\n',
#  '2018-09-23,65,39,40\n',
#  '2018-09-30,62,42,46\n',
#  '2018-10-07,64,39,41\n',
#  '2018-10-14,62,42,39\n',
#  '2018-10-21,60,42,37\n',
#  '2018-10-28,58,40,36\n',
#  '2018-11-04,59,45,36\n',
#  '2018-11-11,61,43,37\n',
#  '2018-11-18,52,51,38\n',
#  '2018-11-25,59,52,41\n',
#  '2018-12-02,63,54,41\n',
#  '2018-12-09,64,52,37\n',
#  '2018-12-16,58,53,34\n',
#  '2018-12-23,50,70,38\n',
#  '2018-12-30,54,62,42\n',
#  '2019-01-06,59,50,47\n',
#  '2019-01-13,59,56,43\n',
#  '2019-01-20,59,48,41\n',
#  '2019-01-27,68,46,40\n',
#  '2019-02-03,63,43,42\n',
#  '2019-02-10,61,43,45\n',
#  '2019-02-17,66,51,39\n',
#  '2019-02-24,63,47,37\n',
#  '2019-03-03,55,46,40\n',
#  '2019-03-10,60,38,39\n',
#  '2019-03-17,58,42,33\n',
#  '2019-03-24,59,39,39\n',
#  '2019-03-31,60,38,43\n',
#  '2019-04-07,66,42,38\n',
#  '2019-04-14,60,39,38\n',
#  '2019-04-21,62,34,39\n',
#  '2019-04-28,59,39,40\n',
#  '2019-05-05,63,39,37\n',
#  '2019-05-12,66,34,35\n',
#  '2019-05-19,64,34,42\n',
#  '2019-05-26,69,38,38\n',
#  '2019-06-02,66,42,33\n',
#  '2019-06-09,72,39,41\n',
#  '2019-06-16,71,40,38\n',
#  '2019-06-23,68,41,42\n',
#  '2019-06-30,64,39,40\n',
#  '2019-07-07,75,38,44\n',
#  '2019-07-14,67,38,41\n',
#  '2019-07-21,71,44,39\n',
#  '2019-07-28,71,38,37\n',
#  '2019-08-04,66,33,34\n',
#  '2019-08-11,69,41,41\n',
#  '2019-08-18,78,41,48\n',
#  '2019-08-25,65,38,40\n',
#  '2019-09-01,74,40,45\n',
#  '2019-09-08,73,48,46\n',
#  '2019-09-15,76,42,44\n',
#  '2019-09-22,69,41,48\n',
#  '2019-09-29,67,41,43\n',
#  '2019-10-06,65,40,36\n',
#  '2019-10-13,71,39,42\n',
#  '2019-10-20,63,41,39\n',
#  '2019-10-27,66,38,40\n',
#  '2019-11-03,67,48,42\n',
#  '2019-11-10,68,41,48\n',
#  '2019-11-17,69,41,40\n',
#  '2019-11-24,64,46,39\n',
#  '2019-12-01,69,47,40\n',
#  '2019-12-08,64,42,34\n',
#  '2019-12-15,71,46,40\n',
#  '2019-12-22,64,60,39\n',
#  '2019-12-29,56,56,41\n',
#  '2020-01-05,77,52,41\n',
#  '2020-01-12,69,47,44\n',
#  '2020-01-19,71,42,43\n',
#  '2020-01-26,69,42,40\n',
#  '2020-02-02,68,47,39\n',
#  '2020-02-09,71,40,39\n',
#  '2020-02-16,73,43,40\n',
#  '2020-02-23,72,40,42\n',
#  '2020-03-01,64,44,38\n',
#  '2020-03-08,59,38,34\n',
#  '2020-03-15,70,67,42\n',
#  '2020-03-22,79,96,48\n',
#  '2020-03-29,86,100,46\n',
#  '2020-04-05,79,89,45\n',
#  '2020-04-12,84,96,54\n',
#  '2020-04-19,81,82,46\n',
#  '2020-04-26,84,81,49\n',
#  '2020-05-03,80,69,47\n',
#  '2020-05-10,74,67,45\n',
#  '2020-05-17,79,67,43\n',
#  '2020-05-24,75,55,41\n',
#  '2020-05-31,67,51,42\n',
#  '2020-06-07,75,54,44\n',
#  '2020-06-14,72,51,44\n',
#  '2020-06-21,70,52,45\n',
#  '2020-06-28,79,50,43\n',
#  '2020-07-05,76,50,41\n',
#  '2020-07-12,78,49,43\n',
#  '2020-07-19,75,44,47\n',
#  '2020-07-26,73,50,42\n',
#  '2020-08-02,67,49,40\n',
#  '2020-08-09,73,48,40\n',
#  '2020-08-16,70,44,40\n',
#  '2020-08-23,70,43,43\n',
#  '2020-08-30,71,49,42\n',
#  '2020-09-06,67,49,39\n',
#  '2020-09-13,64,43,44\n',
#  '2020-09-20,62,46,43\n',
#  '2020-09-27,61,44,37\n',
#  '2020-10-04,62,43,40\n',
#  '2020-10-11,50,43,38\n',
#  '2020-10-18,55,42,38\n',
#  '2020-10-25,52,39,34\n',
#  '2020-11-01,42,41,28\n',
#  '2020-11-08,52,44,35\n',
#  '2020-11-15,53,45,41\n',
#  '2020-11-22,51,42,35\n',
#  '2020-11-29,50,44,34\n',
#  '2020-12-06,54,43,35\n',
#  '2020-12-13,52,42,36\n',
#  '2020-12-20,48,56,34\n',
#  '2020-12-27,54,67,36\n',
#  '2021-01-03,58,58,42\n',
#  '2021-01-10,56,52,37\n',
#  '2021-01-17,49,43,38\n',
#  '2021-01-24,50,49,35\n',
#  '2021-01-31,51,47,40\n',
#  '2021-02-07,51,46,33\n',
#  '2021-02-14,54,40,33\n',
#  '2021-02-21,46,39,35\n',
#  '2021-02-28,51,39,32\n',
#  '2021-03-07,47,40,34\n',
#  '2021-03-14,48,38,33\n',
#  '2021-03-21,54,34,34\n',
#  '2021-03-28,50,36,29\n',
#  '2021-04-04,53,35,35\n',
#  '2021-04-11,48,35,41\n',
#  '2021-04-18,51,38,32\n',
#  '2021-04-25,57,35,34\n',
#  '2021-05-02,53,36,31\n',
#  '2021-05-09,61,36,33\n',
#  '2021-05-16,58,35,32\n',
#  '2021-05-23,57,36,39\n',
#  '2021-05-30,62,36,36\n',
#  '2021-06-06,53,33,34\n',
#  '2021-06-13,59,34,30\n',
#  '2021-06-20,55,32,32\n',
#  '2021-06-27,52,34,32\n',
#  '2021-07-04,57,36,32\n',
#  '2021-07-11,62,34,34\n',
#  '2021-07-18,54,35,34\n',
#  '2021-07-25,56,31,37\n',
#  '2021-08-01,51,29,33\n',
#  '2021-08-08,51,32,33\n',
#  '2021-08-15,52,38,30\n',
#  '2021-08-22,53,31,37\n',
#  '2021-08-29,49,31,36\n',
#  '2021-09-05,52,34,41\n',
#  '2021-09-12,50,37,34\n',
#  '2021-09-19,58,38,38\n',
#  '2021-09-26,55,34,35\n',
#  '2021-10-03,50,33,39\n',
#  '2021-10-10,50,36,35\n',
#  '2021-10-17,55,32,32\n',
#  '2021-10-24,54,34,34\n',
#  '2021-10-31,50,42,33\n',
#  '2021-11-07,53,38,36\n',
#  '2021-11-14,53,37,38\n',
#  '2021-11-21,51,40,33\n',
#  '2021-11-28,52,40,32\n',
#  '2021-12-05,58,43,30\n',
#  '2021-12-12,57,41,36\n',
#  '2021-12-19,51,51,34\n',
#  '2021-12-26,52,60,32\n',
#  '2022-01-02,59,49,35\n',
#  '2022-01-09,54,48,37\n',
#  '2022-01-16,59,39,34\n',
#  '2022-01-23,57,38,36\n',
#  '2022-01-30,54,40,37\n',
#  '2022-02-06,58,41,35\n',
#  '2022-02-13,53,38,35\n',
#  '2022-02-20,54,37,33\n',
#  '2022-02-27,56,34,36\n',
#  '2022-03-06,55,35,33\n',
#  '2022-03-13,49,31,31\n',
#  '2022-03-20,57,31,37\n',
#  '2022-03-27,52,33,32\n',
#  '2022-04-03,58,34,30\n',
#  '2022-04-10,52,34,33\n',
#  '2022-04-17,54,35,32\n',
#  '2022-04-24,55,28,30\n',
#  '2022-05-01,53,33,35\n',
#  '2022-05-08,53,31,34\n',
#  '2022-05-15,0,0,0\n']

# %%
week = []
python_data = []
piano_data = []
german_data = []

# %%
# collect each data column in an list

for line in data:
    line = line[:-1]
    line = line.split(',')
    week.append(line[0])
    python_data.append(int(line[1]))
    piano_data.append(int(line[2]))
    german_data.append(int(line[3]))

# %%
week
# Out:
# ['2017-05-21',
#  '2017-05-28',
#  '2017-06-04',
#  '2017-06-11',
#  '2017-06-18',
#  '2017-06-25',
#  '2017-07-02',
#  '2017-07-09',
#  '2017-07-16',
#  '2017-07-23',
#  '2017-07-30',
#  '2017-08-06',
#  '2017-08-13',
#  '2017-08-20',
#  '2017-08-27',
#  '2017-09-03',
#  '2017-09-10',
#  '2017-09-17',
#  '2017-09-24',
#  '2017-10-01',
#  '2017-10-08',
#  '2017-10-15',
#  '2017-10-22',
#  '2017-10-29',
#  '2017-11-05',
#  '2017-11-12',
#  '2017-11-19',
#  '2017-11-26',
#  '2017-12-03',
#  '2017-12-10',
#  '2017-12-17',
#  '2017-12-24',
#  '2017-12-31',
#  '2018-01-07',
#  '2018-01-14',
#  '2018-01-21',
#  '2018-01-28',
#  '2018-02-04',
#  '2018-02-11',
#  '2018-02-18',
#  '2018-02-25',
#  '2018-03-04',
#  '2018-03-11',
#  '2018-03-18',
#  '2018-03-25',
#  '2018-04-01',
#  '2018-04-08',
#  '2018-04-15',
#  '2018-04-22',
#  '2018-04-29',
#  '2018-05-06',
#  '2018-05-13',
#  '2018-05-20',
#  '2018-05-27',
#  '2018-06-03',
#  '2018-06-10',
#  '2018-06-17',
#  '2018-06-24',
#  '2018-07-01',
#  '2018-07-08',
#  '2018-07-15',
#  '2018-07-22',
#  '2018-07-29',
#  '2018-08-05',
#  '2018-08-12',
#  '2018-08-19',
#  '2018-08-26',
#  '2018-09-02',
#  '2018-09-09',
#  '2018-09-16',
#  '2018-09-23',
#  '2018-09-30',
#  '2018-10-07',
#  '2018-10-14',
#  '2018-10-21',
#  '2018-10-28',
#  '2018-11-04',
#  '2018-11-11',
#  '2018-11-18',
#  '2018-11-25',
#  '2018-12-02',
#  '2018-12-09',
#  '2018-12-16',
#  '2018-12-23',
#  '2018-12-30',
#  '2019-01-06',
#  '2019-01-13',
#  '2019-01-20',
#  '2019-01-27',
#  '2019-02-03',
#  '2019-02-10',
#  '2019-02-17',
#  '2019-02-24',
#  '2019-03-03',
#  '2019-03-10',
#  '2019-03-17',
#  '2019-03-24',
#  '2019-03-31',
#  '2019-04-07',
#  '2019-04-14',
#  '2019-04-21',
#  '2019-04-28',
#  '2019-05-05',
#  '2019-05-12',
#  '2019-05-19',
#  '2019-05-26',
#  '2019-06-02',
#  '2019-06-09',
#  '2019-06-16',
#  '2019-06-23',
#  '2019-06-30',
#  '2019-07-07',
#  '2019-07-14',
#  '2019-07-21',
#  '2019-07-28',
#  '2019-08-04',
#  '2019-08-11',
#  '2019-08-18',
#  '2019-08-25',
#  '2019-09-01',
#  '2019-09-08',
#  '2019-09-15',
#  '2019-09-22',
#  '2019-09-29',
#  '2019-10-06',
#  '2019-10-13',
#  '2019-10-20',
#  '2019-10-27',
#  '2019-11-03',
#  '2019-11-10',
#  '2019-11-17',
#  '2019-11-24',
#  '2019-12-01',
#  '2019-12-08',
#  '2019-12-15',
#  '2019-12-22',
#  '2019-12-29',
#  '2020-01-05',
#  '2020-01-12',
#  '2020-01-19',
#  '2020-01-26',
#  '2020-02-02',
#  '2020-02-09',
#  '2020-02-16',
#  '2020-02-23',
#  '2020-03-01',
#  '2020-03-08',
#  '2020-03-15',
#  '2020-03-22',
#  '2020-03-29',
#  '2020-04-05',
#  '2020-04-12',
#  '2020-04-19',
#  '2020-04-26',
#  '2020-05-03',
#  '2020-05-10',
#  '2020-05-17',
#  '2020-05-24',
#  '2020-05-31',
#  '2020-06-07',
#  '2020-06-14',
#  '2020-06-21',
#  '2020-06-28',
#  '2020-07-05',
#  '2020-07-12',
#  '2020-07-19',
#  '2020-07-26',
#  '2020-08-02',
#  '2020-08-09',
#  '2020-08-16',
#  '2020-08-23',
#  '2020-08-30',
#  '2020-09-06',
#  '2020-09-13',
#  '2020-09-20',
#  '2020-09-27',
#  '2020-10-04',
#  '2020-10-11',
#  '2020-10-18',
#  '2020-10-25',
#  '2020-11-01',
#  '2020-11-08',
#  '2020-11-15',
#  '2020-11-22',
#  '2020-11-29',
#  '2020-12-06',
#  '2020-12-13',
#  '2020-12-20',
#  '2020-12-27',
#  '2021-01-03',
#  '2021-01-10',
#  '2021-01-17',
#  '2021-01-24',
#  '2021-01-31',
#  '2021-02-07',
#  '2021-02-14',
#  '2021-02-21',
#  '2021-02-28',
#  '2021-03-07',
#  '2021-03-14',
#  '2021-03-21',
#  '2021-03-28',
#  '2021-04-04',
#  '2021-04-11',
#  '2021-04-18',
#  '2021-04-25',
#  '2021-05-02',
#  '2021-05-09',
#  '2021-05-16',
#  '2021-05-23',
#  '2021-05-30',
#  '2021-06-06',
#  '2021-06-13',
#  '2021-06-20',
#  '2021-06-27',
#  '2021-07-04',
#  '2021-07-11',
#  '2021-07-18',
#  '2021-07-25',
#  '2021-08-01',
#  '2021-08-08',
#  '2021-08-15',
#  '2021-08-22',
#  '2021-08-29',
#  '2021-09-05',
#  '2021-09-12',
#  '2021-09-19',
#  '2021-09-26',
#  '2021-10-03',
#  '2021-10-10',
#  '2021-10-17',
#  '2021-10-24',
#  '2021-10-31',
#  '2021-11-07',
#  '2021-11-14',
#  '2021-11-21',
#  '2021-11-28',
#  '2021-12-05',
#  '2021-12-12',
#  '2021-12-19',
#  '2021-12-26',
#  '2022-01-02',
#  '2022-01-09',
#  '2022-01-16',
#  '2022-01-23',
#  '2022-01-30',
#  '2022-02-06',
#  '2022-02-13',
#  '2022-02-20',
#  '2022-02-27',
#  '2022-03-06',
#  '2022-03-13',
#  '2022-03-20',
#  '2022-03-27',
#  '2022-04-03',
#  '2022-04-10',
#  '2022-04-17',
#  '2022-04-24',
#  '2022-05-01',
#  '2022-05-08',
#  '2022-05-15']

# %%
python_data
# Out:
# [61,
#  57,
#  56,
#  63,
#  59,
#  56,
#  57,
#  64,
#  62,
#  62,
#  63,
#  58,
#  63,
#  62,
#  52,
#  64,
#  58,
#  61,
#  66,
#  61,
#  59,
#  58,
#  55,
#  54,
#  63,
#  59,
#  62,
#  65,
#  63,
#  62,
#  59,
#  57,
#  59,
#  65,
#  66,
#  65,
#  64,
#  62,
#  58,
#  56,
#  61,
#  59,
#  67,
#  60,
#  60,
#  60,
#  59,
#  66,
#  60,
#  59,
#  64,
#  61,
#  66,
#  61,
#  65,
#  59,
#  61,
#  67,
#  62,
#  63,
#  61,
#  69,
#  70,
#  68,
#  61,
#  64,
#  61,
#  63,
#  61,
#  60,
#  65,
#  62,
#  64,
#  62,
#  60,
#  58,
#  59,
#  61,
#  52,
#  59,
#  63,
#  64,
#  58,
#  50,
#  54,
#  59,
#  59,
#  59,
#  68,
#  63,
#  61,
#  66,
#  63,
#  55,
#  60,
#  58,
#  59,
#  60,
#  66,
#  60,
#  62,
#  59,
#  63,
#  66,
#  64,
#  69,
#  66,
#  72,
#  71,
#  68,
#  64,
#  75,
#  67,
#  71,
#  71,
#  66,
#  69,
#  78,
#  65,
#  74,
#  73,
#  76,
#  69,
#  67,
#  65,
#  71,
#  63,
#  66,
#  67,
#  68,
#  69,
#  64,
#  69,
#  64,
#  71,
#  64,
#  56,
#  77,
#  69,
#  71,
#  69,
#  68,
#  71,
#  73,
#  72,
#  64,
#  59,
#  70,
#  79,
#  86,
#  79,
#  84,
#  81,
#  84,
#  80,
#  74,
#  79,
#  75,
#  67,
#  75,
#  72,
#  70,
#  79,
#  76,
#  78,
#  75,
#  73,
#  67,
#  73,
#  70,
#  70,
#  71,
#  67,
#  64,
#  62,
#  61,
#  62,
#  50,
#  55,
#  52,
#  42,
#  52,
#  53,
#  51,
#  50,
#  54,
#  52,
#  48,
#  54,
#  58,
#  56,
#  49,
#  50,
#  51,
#  51,
#  54,
#  46,
#  51,
#  47,
#  48,
#  54,
#  50,
#  53,
#  48,
#  51,
#  57,
#  53,
#  61,
#  58,
#  57,
#  62,
#  53,
#  59,
#  55,
#  52,
#  57,
#  62,
#  54,
#  56,
#  51,
#  51,
#  52,
#  53,
#  49,
#  52,
#  50,
#  58,
#  55,
#  50,
#  50,
#  55,
#  54,
#  50,
#  53,
#  53,
#  51,
#  52,
#  58,
#  57,
#  51,
#  52,
#  59,
#  54,
#  59,
#  57,
#  54,
#  58,
#  53,
#  54,
#  56,
#  55,
#  49,
#  57,
#  52,
#  58,
#  52,
#  54,
#  55,
#  53,
#  53,
#  0]

# %%
import matplotlib.pyplot as plt

plt.plot(python_data, label='learn python')
plt.plot(german_data, label='learn german')
plt.plot(piano_data,  label='learn piano')
plt.legend()

# %%
week[150]
