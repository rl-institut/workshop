# %% [markdown]
# # Postprocessing and plots
#
# The outputlib module
# https://oemof.readthedocs.io/en/stable/api/oemof.outputlib.html

# %% [markdown]
# ## Imports pandas, matplotlib and oemof

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams

import oemof.solph as solph
import oemof.outputlib as outputlib
from oemof.tools.economics import annuity

# %%
# %matplotlib inline
rcParams['figure.figsize'] = [20.0, 7.0]
rcParams['font.size'] = 25

# %% [markdown]
# ## Restore the energysystem with results

# %%
energysystem = solph.EnergySystem()
energysystem.restore(dpath=None, filename=None)
# Out:
# 'Attributes restored from: /home/jann/.oemof/dumps/es_dump.oemof'

# %% [markdown]
# ## Filter the dictionary using outputlib
# ### Get all the flows into and out of the electricity bus

# %%
results_bus_el = outputlib.views.node(energysystem.results['main'], 'electricity')['sequences']
# results_bus_th = outputlib.views.node(energysystem.results['main'], 'heat')['sequences']
results_bus_el.columns = [col[0] for col in results_bus_el.columns]
results_bus_el.index.name = 'timeindex'
results_bus_el
# Out:
#                      (chp_gas, electricity)  (electricity, demand_el)  \
# timeindex
# 2016-01-01 00:00:00                4.408357                 52.169653
# 2016-01-01 01:00:00                4.501334                 52.169653
# 2016-01-01 02:00:00                4.707776                 47.392644
# 2016-01-01 03:00:00                5.221512                 45.197772
# 2016-01-01 04:00:00                6.525410                 44.189789
# 2016-01-01 05:00:00               16.241444                 42.397456
# 2016-01-01 06:00:00                6.849886                 39.072422
# 2016-01-01 07:00:00                7.920355                 38.786609
# 2016-01-01 08:00:00                9.186904                 39.558959
# 2016-01-01 09:00:00                8.553791                 42.074553
# 2016-01-01 10:00:00                7.890080                 44.811597
# 2016-01-01 11:00:00                7.508906                 48.223902
# 2016-01-01 12:00:00                7.307707                 49.207885
# 2016-01-01 13:00:00                7.311994                 48.234811
# 2016-01-01 14:00:00                7.403347                 47.857363
# 2016-01-01 15:00:00                7.628014                 47.914089
# 2016-01-01 16:00:00                8.026032                 51.140943
# 2016-01-01 17:00:00                8.570015                 56.369581
# 2016-01-01 18:00:00                8.918288                 57.745194
# 2016-01-01 19:00:00                8.512484                 56.860482
# 2016-01-01 20:00:00                7.880310                 54.858698
# 2016-01-01 21:00:00                6.554039                 54.772517
# 2016-01-01 22:00:00                4.521683                 56.029223
# 2016-01-01 23:00:00                4.325206                 52.417285
# 2016-01-02 00:00:00                5.182801                 49.079160
# 2016-01-02 01:00:00                5.323458                 47.256282
# 2016-01-02 02:00:00                5.549307                 46.174119
# 2016-01-02 03:00:00                5.951316                 45.731217
# 2016-01-02 04:00:00                7.003009                 46.577748
# 2016-01-02 05:00:00                9.272345                 48.655895
# ...                                     ...                       ...
# 2016-12-29 18:00:00                9.584808                 65.516697
# 2016-12-29 19:00:00               12.354828                 63.114556
# 2016-12-29 20:00:00                8.523127                 60.030609
# 2016-12-29 21:00:00                6.747984                 58.744449
# 2016-12-29 22:00:00                7.815674                 59.690251
# 2016-12-29 23:00:00                5.170621                 56.753574
# 2016-12-30 00:00:00                1.695962                 53.454722
# 2016-12-30 01:00:00                5.472345                 50.165687
# 2016-12-30 02:00:00                5.765132                 48.219538
# 2016-12-30 10:00:00             7.684736
# 2016-12-30 11:00:00             8.523710
# 2016-12-30 12:00:00            10.553809
# 2016-12-30 13:00:00            11.928724
# 2016-12-30 14:00:00            10.020964
# 2016-12-30 15:00:00             7.305568
# 2016-12-30 16:00:00             6.790836
# 2016-12-30 17:00:00             5.798525
# 2016-12-30 18:00:00             5.672065
# 2016-12-30 19:00:00             5.805467
# 2016-12-30 20:00:00             6.411220
# 2016-12-30 21:00:00             7.787226
# 2016-12-30 22:00:00             9.418889
# 2016-12-30 23:00:00            14.060704
#
# [8760 rows x 9 columns]

# %% [markdown]
# ### Prepare input parameters for postprocessing

# %%
params = energysystem.params
params
# Out:
# {("<oemof.solph.network.Bus: 'coal'>",
#   "<oemof.solph.network.Transformer: 'pp_coal'>"): {'scalars': fixed                                                                  False
#   label                      EdgeLabel(input="<oemof.solph.network.Bus: 'co...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Bus: 'gas'>",
#   "<oemof.solph.network.Transformer: 'chp_gas'>"): {'scalars': fixed                                                                  False
#   label                      EdgeLabel(input="<oemof.solph.network.Bus: 'ga...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Bus: 'electricity'>",
#   "<oemof.solph.network.Sink: 'demand_el'>"): {'scalars': fixed                                                                   True
#   nominal_value                                                             85
#   label                      EdgeLabel(input="<oemof.solph.network.Bus: 'el...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences':       actual_value
#   0         0.613761
#   1         0.613761
#   2         0.557561
#   3         0.531738
#   4         0.519880
#   5         0.498794
#   6         0.459676
#   7         0.456313
#   8         0.465400
#   9         0.494995
#   10        0.527195
#   11        0.567340
#   12        0.578916
#   13        0.567468
#   14        0.563028
#   15        0.563695
#   16        0.601658
#   17        0.663172
#   18        0.679355
#   19        0.668947
#   20        0.645396
#   21        0.644383
#   22        0.659167
#   23        0.616674
#   24        0.577402
#   25        0.555956
#   26        0.543225
#   27        0.538014
#   28        0.547974
#   29        0.572422
#   ...            ...
#   8730      0.770785
#   8731      0.742524
#   8732      0.706242
#   8733      0.691111
#   8734      0.702238
#   8735      0.667689
#   8736      0.628879
#   8737      0.590185
#   8738      0.567289
#   8739      0.561706
#   8740      0.556251
#   8741      0.545843
#   8742      0.522934
#   8743      0.541377
#   8744      0.571036
#   8745      0.602428
#   8746      0.627583
#   8747      0.654842
#   8748      0.657640
#   8749      0.643369
#   8750      0.622783
#   8751      0.617739
#   8752      0.652930
#   8753      0.707205
#   8754      0.700916
#   8755      0.662016
#   8756      0.620588
#   8757      0.618137
#   8758      0.634321
#   8759      0.613966
#
#   [8760 rows x 1 columns]},
#  ("<oemof.solph.network.Bus: 'electricity'>",
#   "<oemof.solph.components.GenericStorage: 'storage_el'>"): {'scalars': fixed                                                                  False
#   nominal_value                                                              9
#   label                      EdgeLabel(input="<oemof.solph.network.Bus: 'el...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Bus: 'electricity'>",
#   "<oemof.solph.network.Sink: 'excess_el'>"): {'scalars': fixed                                                                  False
#   label                      EdgeLabel(input="<oemof.solph.network.Bus: 'el...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Bus: 'heat'>",
#   "<oemof.solph.network.Sink: 'demand_th'>"): {'scalars': fixed                                                                   True
#   nominal_value                                                             40
#   label                      EdgeLabel(input="<oemof.solph.network.Bus: 'he...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences':       actual_value
#   0         0.146945
#   1         0.150044
#   2         0.156926
#   3         0.174050
#   4         0.217514
#   5         0.299317
#   6         0.354162
#   7         0.331608
#   8         0.306230
#   9         0.285126
#   10        0.263003
#   11        0.250297
#   12        0.243590
#   13        0.243733
#   14        0.246778
#   15        0.254267
#   16        0.267534
#   17        0.285667
#   18        0.297276
#   19        0.283749
#   20        0.262677
#   21        0.218468
#   22        0.150723
#   23        0.144174
#   24        0.172760
#   25        0.177449
#   26        0.184977
#   27        0.198377
#   28        0.233434
#   29        0.309078
#   ...            ...
#   8730      0.319494
#   8731      0.308096
#   8732      0.287353
#   8733      0.246196
#   8734      0.176694
#   8735      0.169607
#   8736      0.179479
#   8737      0.184350
#   8738      0.192171
#   8739      0.206093
#   8740      0.242512
#   8741      0.321099
#   8742      0.376240
#   8743      0.363225
#   8744      0.342119
#   8745      0.323363
#   8746      0.300262
#   8747      0.286402
#   8748      0.277603
#   8749      0.276330
#   8750      0.280676
#   8751      0.290193
#   8752      0.300801
#   8753      0.317976
#   8754      0.331919
#   8755      0.320078
#   8756      0.298529
#   8757      0.255771
#   8758      0.183566
#   8759      0.176203
#
#   [8760 rows x 1 columns]},
#  ("<oemof.solph.network.Bus: 'heat'>",
#   "<oemof.solph.components.GenericStorage: 'storage_th'>"): {'scalars': fixed                                                                  False
#   nominal_value                                                            200
#   label                      EdgeLabel(input="<oemof.solph.network.Bus: 'he...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Source: 'source_gas'>",
#   "<oemof.solph.network.Bus: 'gas'>"): {'scalars': fixed                                                                  False
#   label                      EdgeLabel(input="<oemof.solph.network.Source: ...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                            30
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Source: 'source_coal'>",
#   "<oemof.solph.network.Bus: 'coal'>"): {'scalars': fixed                                                                  False
#   label                      EdgeLabel(input="<oemof.solph.network.Source: ...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                            30
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Source: 'wind'>",
#   "<oemof.solph.network.Bus: 'electricity'>"): {'scalars': fixed                                                                   True
#   nominal_value                                                             60
#   label                      EdgeLabel(input="<oemof.solph.network.Source: ...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences':       actual_value
#   0         0.236754
#   1         0.240720
#   2         0.327421
#   3         0.402503
#   4         0.428876
#   5         0.417830
#   6         0.537042
#   7         0.514438
#   8         0.477117
#   9         0.358395
#   10        0.228767
#   11        0.171902
#   12        0.171416
#   13        0.223516
#   14        0.229786
#   15        0.185748
#   16        0.166806
#   17        0.174860
#   18        0.197805
#   19        0.225774
#   20        0.231848
#   21        0.208974
#   22        0.215986
#   23        0.209108
#   24        0.168191
#   25        0.140124
#   26        0.108434
#   27        0.115527
#   28        0.148271
#   29        0.169588
#   ...            ...
#   8730      0.007523
#   8731      0.012662
#   8732      0.025125
#   8733      0.033274
#   8734      0.031243
#   8735      0.026383
#   8736      0.029313
#   8737      0.045034
#   8738      0.063756
#   8739      0.074870
#   8740      0.067787
#   8741      0.063501
#   8742      0.069293
#   8743      0.072155
#   8744      0.085716
#   8745      0.108674
#   8746      0.128079
#   8747      0.142062
#   8748      0.175897
#   8749      0.198812
#   8750      0.167016
#   8751      0.121759
#   8752      0.113181
#   8753      0.096642
#   8754      0.094534
#   8755      0.096758
#   8756      0.106854
#   8757      0.129787
#   8758      0.156981
#   8759      0.234345
#
#   [8760 rows x 1 columns]},
#  ("<oemof.solph.network.Source: 'pv'>",
#   "<oemof.solph.network.Bus: 'electricity'>"): {'scalars': fixed                                                                   True
#   nominal_value                                                             43
#   label                      EdgeLabel(input="<oemof.solph.network.Source: ...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences':       actual_value
#   0         0.000000
#   1         0.000000
#   2         0.000000
#   3         0.000000
#   4         0.000000
#   5         0.000000
#   6         0.000000
#   7         0.000000
#   8         0.000000
#   9         0.005895
#   10        0.021099
#   11        0.093593
#   12        0.305348
#   13        0.123003
#   14        0.071309
#   15        0.016012
#   16        0.000000
#   17        0.000000
#   18        0.000000
#   19        0.000000
#   20        0.000000
#   21        0.000000
#   22        0.000000
#   23        0.000000
#   24        0.000000
#   25        0.000000
#   26        0.000000
#   27        0.000000
#   28        0.000000
#   29        0.000000
#   ...            ...
#   8730      0.000000
#   8731      0.000000
#   8732      0.000000
#   8733      0.000000
#   8734      0.000000
#   8735      0.000000
#   8736      0.000000
#   8737      0.000000
#   8738      0.000000
#   8739      0.000000
#   8740      0.000000
#   8741      0.000000
#   8742      0.000000
#   8743      0.000000
#   8744      0.000000
#   8745      0.028361
#   8746      0.061009
#   8747      0.038646
#   8748      0.041908
#   8749      0.027936
#   8750      0.009432
#   8751      0.001335
#   8752      0.000000
#   8753      0.000000
#   8754      0.000000
#   8755      0.000000
#   8756      0.000000
#   8757      0.000000
#   8758      0.000000
#   8759      0.000000
#
#   [8760 rows x 1 columns]},
#  ("<oemof.solph.network.Transformer: 'pp_coal'>",
#   "<oemof.solph.network.Bus: 'electricity'>"): {'scalars': emission_factor                                                        0.335
#   fixed                                                                  False
#   nominal_value                                                             50
#   label                      EdgeLabel(input="<oemof.solph.network.Transfor...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Transformer: 'chp_gas'>",
#   "<oemof.solph.network.Bus: 'electricity'>"): {'scalars': emission_factor                                                        0.202
#   fixed                                                                  False
#   nominal_value                                                             30
#   label                      EdgeLabel(input="<oemof.solph.network.Transfor...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Transformer: 'chp_gas'>",
#   "<oemof.solph.network.Bus: 'heat'>"): {'scalars': fixed                                                                  False
#   nominal_value                                                             40
#   label                      EdgeLabel(input="<oemof.solph.network.Transfor...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.components.GenericStorage: 'storage_el'>",
#   "<oemof.solph.network.Bus: 'electricity'>"): {'scalars': fixed                                                                  False
#   nominal_value                                                              9
#   label                      EdgeLabel(input="<oemof.solph.components.Gener...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.components.GenericStorage: 'storage_th'>",
#   "<oemof.solph.network.Bus: 'heat'>"): {'scalars': fixed                                                                  False
#   nominal_value                                                            200
#   label                      EdgeLabel(input="<oemof.solph.components.Gener...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                             0
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Source: 'shortage_el'>",
#   "<oemof.solph.network.Bus: 'electricity'>"): {'scalars': fixed                                                                  False
#   label                      EdgeLabel(input="<oemof.solph.network.Source: ...
#   max                                                                        1
#   min                                                                        0
#   negative_gradient_costs                                                    0
#   positive_gradient_costs                                                    0
#   variable_costs                                                        100000
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Bus: 'coal'>", None): {'scalars': balanced    True
#   label       coal
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Bus: 'gas'>", None): {'scalars': balanced    True
#   label        gas
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Bus: 'electricity'>",
#   None): {'scalars': balanced           True
#   label       electricity
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Bus: 'heat'>", None): {'scalars': balanced    True
#   label       heat
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Source: 'source_gas'>",
#   None): {'scalars': label    source_gas
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Source: 'source_coal'>",
#   None): {'scalars': label    source_coal
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Source: 'wind'>", None): {'scalars': label    wind
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Source: 'pv'>", None): {'scalars': label    pv
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Sink: 'demand_el'>",
#   None): {'scalars': label    demand_el
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Sink: 'demand_th'>",
#   None): {'scalars': label    demand_th
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Transformer: 'pp_coal'>",
#   None): {'scalars': label                             pp_coal
#   conversion_factors_electricity       0.39
#   conversion_factors_coal                 1
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Transformer: 'chp_gas'>",
#   None): {'scalars': label                             chp_gas
#   conversion_factors_electricity        0.3
#   conversion_factors_heat               0.4
#   conversion_factors_gas                  1
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.components.GenericStorage: 'storage_el'>",
#   None): {'scalars': balanced                           True
#   initial_storage_level                 0
#   label                        storage_el
#   nominal_storage_capacity           1000
#   inflow_conversion_factor            0.9
#   loss_rate                          0.01
#   max_storage_level                   0.9
#   min_storage_level                     0
#   outflow_conversion_factor           0.9
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.components.GenericStorage: 'storage_th'>",
#   None): {'scalars': balanced                           True
#   initial_storage_level                 0
#   label                        storage_th
#   nominal_storage_capacity           1000
#   inflow_conversion_factor            0.9
#   loss_rate                          0.01
#   max_storage_level                   0.9
#   min_storage_level                     0
#   outflow_conversion_factor           0.9
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Sink: 'excess_el'>",
#   None): {'scalars': label    excess_el
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []},
#  ("<oemof.solph.network.Source: 'shortage_el'>",
#   None): {'scalars': label    shortage_el
#   dtype: object, 'sequences': Empty DataFrame
#   Columns: []
#   Index: []}}

# %%
def convert_params_to_dataframe(params):
    r"""
    
    """    
    param_df = pd.DataFrame()
    for key in params.keys():
        new_row = params[key]['scalars']
        label = tuple(map(str, key)) if isinstance(key, tuple) else str(key)
        new_row['label'] = label
        new_row['from'] = label[0]
        new_row['to'] = label[1]
        param_df = param_df.append(new_row, ignore_index=True)
        
    param_df['fixed'] = param_df['fixed'].astype('bool')
    param_df = param_df[param_df.columns.drop('label').insert(0, 'label')]
    param_df = param_df.set_index('label')
    return param_df

params_df = convert_params_to_dataframe(params)
params_df.head()
# Out:
#                            fixed         from  max  min  \
# label
# (coal, pp_coal)            False         coal  1.0  0.0
# (gas, chp_gas)             False          gas  1.0  0.0
# (electricity, demand_el)    True  electricity  1.0  0.0
# (electricity, storage_el)  False  electricity  1.0  0.0
# (electricity, excess_el)   False  electricity  1.0  0.0
#
#                            negative_gradient_costs  positive_gradient_costs  \
# label
# (coal, pp_coal)                                0.0                      0.0
# (gas, chp_gas)                                 0.0                      0.0
# (electricity, demand_el)                       0.0                      0.0
# (electricity, storage_el)                      0.0                      0.0
# (electricity, excess_el)                       0.0                      0.0
#
#                                    to  variable_costs  nominal_value  \
# label
# (coal, pp_coal)               pp_coal             0.0            NaN
# (gas, chp_gas)                chp_gas             0.0            NaN
# (electricity, demand_el)    demand_el             0.0           85.0
# (electricity, storage_el)  storage_el             0.0            9.0
# (electricity, excess_el)    excess_el             0.0            NaN
#
#                            emission_factor  ...  \
# label                                       ...
# (coal, pp_coal)                        NaN  ...
# (gas, chp_gas)                         NaN  ...
# (electricity, demand_el)               NaN  ...
# (electricity, storage_el)              NaN  ...
# (electricity, excess_el)               NaN  ...
#
#                            conversion_factors_electricity  \
# label
# (coal, pp_coal)                                       NaN
# (gas, chp_gas)                                        NaN
# (electricity, demand_el)                              NaN
# (electricity, storage_el)                             NaN
# (electricity, excess_el)                              NaN
#
#                            conversion_factors_gas  conversion_factors_heat  \
# label
# (coal, pp_coal)                               NaN                      NaN
# (gas, chp_gas)                                NaN                      NaN
# (electricity, demand_el)                      NaN                      NaN
# (electricity, storage_el)                     NaN                      NaN
# (electricity, excess_el)                      NaN                      NaN
#
#                            inflow_conversion_factor  initial_storage_level  \
# label
# (coal, pp_coal)                                 NaN                    NaN
# (gas, chp_gas)                                  NaN                    NaN
# (electricity, demand_el)                        NaN                    NaN
# (electricity, storage_el)                       NaN                    NaN
# (electricity, excess_el)                        NaN                    NaN
#
#                            loss_rate  max_storage_level  min_storage_level  \
# label
# (coal, pp_coal)                  NaN                NaN                NaN
# (gas, chp_gas)                   NaN                NaN                NaN
# (electricity, demand_el)         NaN                NaN                NaN
# (electricity, storage_el)        NaN                NaN                NaN
# (electricity, excess_el)         NaN                NaN                NaN
#
#                            nominal_storage_capacity  outflow_conversion_factor
# label
# (coal, pp_coal)                                 NaN                        NaN
# (gas, chp_gas)                                  NaN                        NaN
# (electricity, demand_el)                        NaN                        NaN
# (electricity, storage_el)                       NaN                        NaN
# (electricity, excess_el)                        NaN                        NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Define color dictionary

# %% [markdown]
# Use color palette generators to generate suitable colors, e.g.:
# http://javier.xyz/cohesive-colors/
# https://colourco.de/
# http://seaborn.pydata.org/tutorial/color_palettes.html

# %%
cdict = {('chp_gas', 'electricity'): '#eeac7e',
        ('pp_coal', 'electricity'): '#0f2e2e',
        ('pv', 'electricity'): '#ffde32',
        ('wind', 'electricity'): '#4ca7c3',
        ('electricity', 'demand_el'): '#000000',
        ('electricity', 'storage_el'): '#E04644',
        ('storage_el', 'electricity'): '#B7D968',
        ('electricity', 'excess_el'): '#C748E2',
        ('shortage_el', 'electricity'): '#B576AD'}

# %% [markdown]
# ## Plot renewable feedin and demand

# %%
seq_re = results_bus_el[[('pv', 'electricity'), ('wind', 'electricity')]]
seq_demand = results_bus_el[('electricity', 'demand_el')]

range_low = 1
range_high = 1000

fig, ax = plt.subplots()
color = [cdict[column] for column in seq_re.columns]
seq_demand[range_low:range_high].plot(ax=ax, linewidth=3, color='k')
seq_re[range_low:range_high].plot.area(ax=ax, color=color)
ax.set_ylim(-90, 130)
ax.set_ylabel('Power in kW')
ax.set_xlabel('Time')
ax.set_title('Electricity demand and renewable feedin')
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5)) # place legend outside of plot
plt.show()

# %% [markdown]
# ## Plot all dispatch

# %%
produced_el = results_bus_el.drop(('electricity', 'demand_el'), axis=1)
produced_el = produced_el.clip(lower=0)
produced_el[('electricity', 'storage_el')] *= -1

# %%
sorted_columns = [('electricity', 'storage_el'),
                  ('storage_el', 'electricity'),
                  ('wind', 'electricity'),
                  ('pv', 'electricity'),
                  ('pp_coal', 'electricity'),
                  ('chp_gas', 'electricity'),
                  ('electricity', 'excess_el'),
                  ('shortage_el', 'electricity')]

produced_el = produced_el[sorted_columns]

# %%
fig, ax = plt.subplots()
color = [cdict[column] for column in produced_el.columns]
produced_el[range_low:range_high].plot.area(ax=ax, color=color)
seq_demand[range_low:range_high].plot(c='k', linewidth=3)
ax.set_ylim(-90, 130)
ax.set_ylabel('Power in kW')
ax.set_xlabel('Time')
ax.set_title('Electricity demand and generation')
ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5)) # place legend outside of plot
plt.show()

# %% [markdown]
# ### Plot Jahresdauerlinie

# %%
sorted_sequences = pd.DataFrame()
for column in results_bus_el.columns:
    sorted_sequences[column]=sorted(results_bus_el[column], reverse=True)

# %%
fig, ax = plt.subplots()
color = [cdict[column] for column in sorted_sequences.columns]
sorted_sequences.plot(ax=ax, color=color, linewidth=5)
ax.set_ylabel('Power in kW')
ax.set_xlabel('Sorted hours')
ax.set_title('Electricity: Annual load duration curve')
legend = plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5)) # place legend outside of plot
plt.show()

# %% [markdown]
# ## Calculate metrics and indicators

# %% [markdown]
# ### Installierte Leistung für Technologie i
# $$P_{inst,i}$$

# %%
to_bus_el = [i[1]=='electricity' for i in params_df.index]
params_df_to_el = params_df.loc[to_bus_el]
params_df_to_el
# Out:
#                             fixed         from  max  min  \
# label
# (wind, electricity)          True         wind  1.0  0.0
# (pv, electricity)            True           pv  1.0  0.0
# (pp_coal, electricity)      False      pp_coal  1.0  0.0
# (chp_gas, electricity)      False      chp_gas  1.0  0.0
# (storage_el, electricity)   False   storage_el  1.0  0.0
# (shortage_el, electricity)  False  shortage_el  1.0  0.0
#
#                             negative_gradient_costs  positive_gradient_costs  \
# label
# (wind, electricity)                             0.0                      0.0
# (pv, electricity)                               0.0                      0.0
# (pp_coal, electricity)                          0.0                      0.0
# (chp_gas, electricity)                          0.0                      0.0
# (storage_el, electricity)                       0.0                      0.0
# (shortage_el, electricity)                      0.0                      0.0
#
#                                      to  variable_costs  nominal_value  \
# label
# (wind, electricity)         electricity             0.0           60.0
# (pv, electricity)           electricity             0.0           43.0
# (pp_coal, electricity)      electricity             0.0           50.0
# (chp_gas, electricity)      electricity             0.0           30.0
# (storage_el, electricity)   electricity             0.0            9.0
# (shortage_el, electricity)  electricity        100000.0            NaN
#
#                             emission_factor  ...  \
# label                                        ...
# (wind, electricity)                     NaN  ...
# (pv, electricity)                       NaN  ...
# (pp_coal, electricity)                0.335  ...
# (chp_gas, electricity)                0.202  ...
# (storage_el, electricity)               NaN  ...
# (shortage_el, electricity)              NaN  ...
#
#                             conversion_factors_electricity  \
# label
# (wind, electricity)                                    NaN
# (pv, electricity)                                      NaN
# (pp_coal, electricity)                                 NaN
# (chp_gas, electricity)                                 NaN
# (storage_el, electricity)                              NaN
# (shortage_el, electricity)                             NaN
#
#                             conversion_factors_gas  conversion_factors_heat  \
# label
# (wind, electricity)                            NaN                      NaN
# (pv, electricity)                              NaN                      NaN
# (pp_coal, electricity)                         NaN                      NaN
# (chp_gas, electricity)                         NaN                      NaN
# (storage_el, electricity)                      NaN                      NaN
# (shortage_el, electricity)                     NaN                      NaN
#
#                             inflow_conversion_factor  initial_storage_level  \
# label
# (wind, electricity)                              NaN                    NaN
# (pv, electricity)                                NaN                    NaN
# (pp_coal, electricity)                           NaN                    NaN
# (chp_gas, electricity)                           NaN                    NaN
# (storage_el, electricity)                        NaN                    NaN
# (shortage_el, electricity)                       NaN                    NaN
#
#                             loss_rate  max_storage_level  min_storage_level  \
# label
# (wind, electricity)               NaN                NaN                NaN
# (pv, electricity)                 NaN                NaN                NaN
# (pp_coal, electricity)            NaN                NaN                NaN
# (chp_gas, electricity)            NaN                NaN                NaN
# (storage_el, electricity)         NaN                NaN                NaN
# (shortage_el, electricity)        NaN                NaN                NaN
#
#                             nominal_storage_capacity  \
# label
# (wind, electricity)                              NaN
# (pv, electricity)                                NaN
# (pp_coal, electricity)                           NaN
# (chp_gas, electricity)                           NaN
# (storage_el, electricity)                        NaN
# (shortage_el, electricity)                       NaN
#
#                             outflow_conversion_factor
# label
# (wind, electricity)                               NaN
# (pv, electricity)                                 NaN
# (pp_coal, electricity)                            NaN
# (chp_gas, electricity)                            NaN
# (storage_el, electricity)                         NaN
# (shortage_el, electricity)                        NaN
#
# [6 rows x 22 columns]

# %%
p_inst = params_df_to_el['nominal_value'].loc[params_df_to_el['nominal_value']>0]
p_inst = p_inst.sort_index()
p_inst = p_inst.rename('installed_capacity')
p_inst
# Out:
# label
# (chp_gas, electricity)       30.0
# (pp_coal, electricity)       50.0
# (pv, electricity)            43.0
# (storage_el, electricity)     9.0
# (wind, electricity)          60.0
# Name: installed_capacity, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16,3))
color = [cdict[label] for label in p_inst.index]
x = [label[0] for label in p_inst.index]
height = p_inst.values
plt.bar(x=x, height=height, color=color)
ax.set_ylabel('Power in kW')
ax.set_xlabel('Technology')
ax.set_title('Electricity: Installed capacity')
plt.show()

# %% [markdown]
# ### Jährliche Energiemenge für Technologie i
# $$E_{ges,i} = \sum_t P_{t,i} \cdot \Delta t$$

# %%
to_bus_el = [column for column in results_bus_el.columns if column[1]=='electricity']
yearly_energy = results_bus_el[to_bus_el].sum()
yearly_energy = yearly_energy.sort_index()
yearly_energy = yearly_energy.rename('yearly_energy')
yearly_energy
# Out:
# (chp_gas, electricity)         40384.149278
# (pp_coal, electricity)        314315.616028
# (pv, electricity)              46995.301771
# (shortage_el, electricity)         0.000000
# (storage_el, electricity)       2517.485282
# (wind, electricity)           134168.601611
# Name: yearly_energy, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16,3))
x = [label[0] for label in yearly_energy.index]
height = yearly_energy.values
color = [cdict[label] for label in yearly_energy.index]
plt.bar(x=x, height=height, color=color)
ax.set_ylabel('Energy in kWh')
ax.set_xlabel('Technology')
ax.set_title('Electricity: yearly energy')
plt.show()

# %% [markdown]
# ### Volllaststunden von Technologie i
# $$t_{Volllast, i} = \frac{E_{ges,i}}{P_{inst,i}}$$

# %%
full_load_hours =  yearly_energy * 1/p_inst
full_load_hours = full_load_hours.rename('full_load_hours')
full_load_hours
# Out:
# (chp_gas, electricity)        1346.138309
# (pp_coal, electricity)        6286.312321
# (pv, electricity)             1092.913995
# (shortage_el, electricity)            NaN
# (storage_el, electricity)      279.720587
# (wind, electricity)           2236.143360
# Name: full_load_hours, dtype: float64

# %% [markdown]
# ### Deckungsgrad von Technologie i
# $$\frac{E_{ges,i}}{\sum_i E_{ges,i}}, \ for \ i \ \neq \ storage $$

# %%
yearly_production = yearly_energy.drop(('storage_el', 'electricity'))
coverage_ratio = (yearly_production * 1/(yearly_production.sum()))
coverage_ratio = coverage_ratio.rename('coverage_ratio')
coverage_ratio
# Out:
# (chp_gas, electricity)        0.075363
# (pp_coal, electricity)        0.586559
# (pv, electricity)             0.087700
# (shortage_el, electricity)    0.000000
# (wind, electricity)           0.250378
# Name: coverage_ratio, dtype: float64

# %% [markdown]
# ### Speicherzyklen
# https://github.com/oemof/cydets

# %%
from cydets.algorithm import detect_cycles

charge_el = results_bus_el[('electricity', 'storage_el')]
cycles = detect_cycles(charge_el)
cycles.head()
# Out:
#               t_start               t_end           t_minimum       doc  \
# 0 2016-01-08 14:00:00 2016-01-17 04:00:00 2016-01-08 16:00:00  0.433196
# 1 2016-01-16 04:00:00 2016-01-17 04:00:00 2016-01-16 05:00:00  0.066035
# 2 2016-01-17 04:00:00 2016-01-18 04:00:00 2016-01-17 07:00:00  1.000000
# 3 2016-01-18 04:00:00 2016-01-21 14:00:00 2016-01-18 06:00:00  1.000000
# 4 2016-01-18 12:00:00 2016-01-20 03:00:00 2016-01-18 13:00:00  0.047696
#
#          duration
# 0 8 days 14:00:00
# 1 1 days 00:00:00
# 2 1 days 00:00:00
# 3 3 days 10:00:00
# 4 1 days 15:00:00

# %%
range_low = 1
range_high = 3000

fig, ax = plt.subplots()
charge_el = charge_el.clip(lower=0)
charge_el[range_low:range_high].plot.area(ax=ax)
for timepoint in cycles['t_start']:
    ax.axvline(x=timepoint, c='r', alpha=0.3)
ax.set_ylabel('Charging power in kW')
ax.set_xlabel('Time')
ax.set_title('Charging profile of electricity storage and detected cycles')
plt.show()

# %% [markdown]
# ### Gesamte Treibhausgasemissionen
#
# Zur Verteilung von Emissionen auf Strom und Wärme siehe diesen Vergleich verschiedener Allokationsmethoden:
#
# https://www.ffe.de/download/wissen/334_Allokationsmethoden_CO2/ET_Allokationsmethoden_CO2.pdf

# %%
emission_factors = params_df['emission_factor'].loc[params_df['emission_factor']>0]
emission_factors
# Out:
# label
# (pp_coal, electricity)    0.335
# (chp_gas, electricity)    0.202
# Name: emission_factor, dtype: float64

# %%
string_results = outputlib.processing.convert_keys_to_strings(energysystem.results['main'])
flows_with_emissions = pd.concat([string_results[i]['sequences']['flow'].rename(i)  for i in emission_factors.index], axis=1)
flows_with_emissions.sum()
# Out:
# pp_coal  electricity    314315.616028
# chp_gas  electricity     40384.149278
# dtype: float64

# %%
emissions = emission_factors * flows_with_emissions.sum()
emissions = emissions.rename('emissions')
emissions
# Out:
# label
# (pp_coal, electricity)    105295.731369
# (chp_gas, electricity)      8157.598154
# Name: emissions, dtype: float64

# %% [markdown]
# ### Gesamtkosten Betrieb
# $$\sum_{i} (C_{FOM,i} + \sum_t P_{t, i} C_{VOM})$$

# %%
variable_costs = params_df['variable_costs'][params_df['variable_costs']>0]
variable_costs
# Out:
# label
# (source_gas, gas)                 30.0
# (source_coal, coal)               30.0
# (shortage_el, electricity)    100000.0
# Name: variable_costs, dtype: float64

# %%
flows_with_variable_costs = pd.concat([string_results[i]['sequences']['flow'].rename(i)  for i in variable_costs.index], axis=1)
summed_variable_costs = variable_costs * flows_with_variable_costs.sum()
summed_variable_costs = summed_variable_costs.rename('summed_variable_costs') 
summed_variable_costs
# Out:
# label
# (source_gas, gas)             4.038415e+06
# (source_coal, coal)           2.417812e+07
# (shortage_el, electricity)    0.000000e+00
# Name: summed_variable_costs, dtype: float64

# %% [markdown]
# ### Gesamtkosten Investition
# $$\sum_{i} C_{capital,i} P_{inst,i}$$

# %%
overnight_costs = pd.Series({('chp_gas', 'electricity'): 888.5,
                   ('pp_coal', 'electricity'): 1554.8,
                   ('pv', 'electricity'): 1000,
                   ('storage_el', 'electricity'): 552,
                   ('wind', 'electricity'): 1377.1}).rename('overnight_cost')

investment_periods = pd.Series({('chp_gas', 'electricity'): 30,
                      ('pp_coal', 'electricity'): 40,
                      ('pv', 'electricity'): 25,
                      ('storage_el', 'electricity'): 10,
                      ('wind', 'electricity'): 25}).rename('investment_period')

wacc = 0.05
def get_annuity(df):
    return annuity(df['overnight_cost'], df['investment_period'], df['wacc'])

annuity_calculation = pd.concat([overnight_costs, investment_periods], axis=1)
annuity_calculation['wacc'] = wacc
annuity_calculation['annuity'] = annuity_calculation.apply(get_annuity, axis=1)
annuity_calculation
# Out:
#                         overnight_cost  investment_period  wacc    annuity
# chp_gas    electricity           888.5                 30  0.05  57.798200
# pp_coal    electricity          1554.8                 40  0.05  90.610885
# pv         electricity          1000.0                 25  0.05  70.952457
# storage_el electricity           552.0                 10  0.05  71.486525
# wind       electricity          1377.1                 25  0.05  97.708629

# %%
investment_costs = annuity_calculation['annuity'] * p_inst
investment_costs = investment_costs.rename('investment_costs')
investment_costs
# Out:
# chp_gas     electricity    1733.946002
# pp_coal     electricity    4530.544249
# pv          electricity    3050.955664
# storage_el  electricity     643.378728
# wind        electricity    5862.517737
# Name: investment_costs, dtype: float64

# %% [markdown]
# ## Gesamtübersicht

# %%
pd.concat([p_inst,
           yearly_energy,
           full_load_hours,
           coverage_ratio,
           emissions,
           summed_variable_costs,
           investment_costs],
          sort=True,
          axis=1)
# Out:
#                             installed_capacity  yearly_energy  \
# (chp_gas, electricity)                    30.0   40384.149278
# (pp_coal, electricity)                    50.0  314315.616028
# (pv, electricity)                         43.0   46995.301771
# (shortage_el, electricity)                 NaN       0.000000
# (source_coal, coal)                        NaN            NaN
# (source_gas, gas)                          NaN            NaN
# (storage_el, electricity)                  9.0    2517.485282
# (wind, electricity)                       60.0  134168.601611
#
#                             full_load_hours  coverage_ratio      emissions  \
# (chp_gas, electricity)          1346.138309        0.075363    8157.598154
# (pp_coal, electricity)          6286.312321        0.586559  105295.731369
# (pv, electricity)               1092.913995        0.087700            NaN
# (shortage_el, electricity)              NaN        0.000000            NaN
# (source_coal, coal)                     NaN             NaN            NaN
# (source_gas, gas)                       NaN             NaN            NaN
# (storage_el, electricity)        279.720587             NaN            NaN
# (wind, electricity)             2236.143360        0.250378            NaN
#
#                             summed_variable_costs  investment_costs
# (chp_gas, electricity)                        NaN       1733.946002
# (pp_coal, electricity)                        NaN       4530.544249
# (pv, electricity)                             NaN       3050.955664
# (shortage_el, electricity)           0.000000e+00               NaN
# (source_coal, coal)                  2.417812e+07               NaN
# (source_gas, gas)                    4.038415e+06               NaN
# (storage_el, electricity)                     NaN        643.378728
# (wind, electricity)                           NaN       5862.517737
